# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **NEW** Unsloth now supports training the new **gpt-oss** model from OpenAI! You can start finetune gpt-oss for free with our **[Colab notebook](https://x.com/UnslothAI/status/1953896997867729075)**!
#
# Unsloth now supports Text-to-Speech (TTS) models. Read our [guide here](https://docs.unsloth.ai/basics/text-to-speech-tts-fine-tuning).
#
# Read our **[Gemma 3N Guide](https://docs.unsloth.ai/basics/gemma-3n-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
# We're installing the latest Torch, Triton, OpenAI's Triton kernels, Transformers and Unsloth!
# !pip install --upgrade -qqq uv
try: import numpy; get_numpy = f"numpy=={numpy.__version__}"
except: get_numpy = "numpy"
# !uv pip install -qqq \
    "torch>=2.8.0" "triton>=3.4.0" {get_numpy} torchvision bitsandbytes "transformers>=4.55.3" \
    "unsloth_zoo[base] @ git+https://github.com/rolandtannous/unsloth-zoo@feat/memory-optimize-mxfp4-dequantization-during-merge" \
    "unsloth[base] @ git+https://github.com/unslothai/unsloth" \
    git+https://github.com/triton-lang/triton.git@05b2c186c1b6c9a08375389d5efe9cb4c401c075#subdirectory=python/triton_kernels
# !uv pip install transformers==4.55.4

# %% [markdown]
# ### Unsloth

# %% [markdown]
# We're about to demonstrate the power of the new OpenAI GPT-OSS 20B model through a finetuning example. To use our `MXFP4` inference example, use this [notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/GPT_OSS_MXFP4_(20B)-Inference.ipynb) instead.

# %%
import os
os.environ["UNSLOTH_ENABLE_LOGGING"] = "1"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024
dtype = None

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/gpt-oss-20b-unsloth-bnb-4bit", # 20B model using bitsandbytes 4bit quantization
    "unsloth/gpt-oss-120b-unsloth-bnb-4bit",
    "unsloth/gpt-oss-20b", # 20B model using MXFP4 format
    "unsloth/gpt-oss-120b",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gpt-oss-120b",
    dtype = dtype, # None for auto detection
    max_seq_length = max_seq_length, # Choose any for long context!
    load_in_4bit = True,  # 4 bit quantization to reduce memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3Processor.__call__.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3RMSNorm.forward.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3Attention.forward.
# ERROR:unsloth_zoo.log:Unsloth: Skipped Gemma3Attention.forward
# Reason: Parameter 'past_key_value' signature changed
# INFO:unsloth_zoo.log:Unsloth: Patched AutoHfQuantizer.merge_quantization_configs.
# ERROR:unsloth_zoo.log:Unsloth: Skipped CsmDepthDecoderForCausalLM.forward
# Reason: New function removed output_attentions and output_hidden_states
# INFO:unsloth_zoo.log:Unsloth: Patched CsmDepthDecoderForCausalLM.forward.
# ERROR:unsloth_zoo.log:Unsloth: Skipped CsmForConditionalGeneration.forward
# Reason: New function removed output_attentions and output_hidden_states
# INFO:unsloth_zoo.log:Unsloth: Patched CsmForConditionalGeneration.forward.
# INFO:unsloth_zoo.log:Unsloth: Patched CsmForConditionalGeneration._merge_input_ids_with_input_values.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3nTextAltUp.predict.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3nTextAltUp.correct.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3nTextAltUp.scale_corrected_output.
# ERROR:unsloth_zoo.log:Unsloth: Skipped Gemma3nModel.get_placeholder_mask
# Reason: Parameter 'input_ids' changed from optional to required
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.swizzle_mxfp4.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.Mxfp4GptOssExperts.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.mlp_forward.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.load_and_swizzle_mxfp4.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.replace_with_mxfp4_linear.
# INFO:unsloth_zoo.log:Unsloth: Patched GptOssAttention.forward.
# ERROR:unsloth_zoo.log:Unsloth: Skipped GptOssAttention.forward
# Reason: Parameter 'past_key_value' signature changed
# INFO:unsloth_zoo.log:Unsloth: Updating GPT OSS Config to fix missing `max_position_embeddings`
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.models.gpt_oss.configuration_gpt_oss.GptOssConfig.
# INFO:unsloth_zoo.log:Unsloth: Patched PixtralAttention.__init__.
# INFO:unsloth_zoo.log:Unsloth: Patched PixtralAttention.forward.
# Unsloth: Successfully added convert_moe_packed_tensors_cpu function.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Bitsandbytes >= 0.46.0 supports torch.compile - enabling.
# Unsloth: Patched cross entropy losses.
# Unsloth: Compiled timm.layers.fast_norm
# Unsloth: Compiled timm.layers.norm_act.BatchNormAct2d
# Unsloth: Compiled timm.layers.norm_act.FrozenBatchNormAct2d
# Unsloth: Compiled timm.layers.norm_act.GroupNorm1Act
# Unsloth: Compiled timm.layers.norm_act.GroupNormAct
# Unsloth: Compiled timm.layers.norm_act.LayerNormAct
# Unsloth: Compiled timm.layers.norm_act.LayerNormAct2d
# Unsloth: Compiled timm.layers.norm_act.LayerNormAct2dFp32
# Unsloth: Compiled timm.layers.norm_act.LayerNormActFp32
# Unsloth: Compiled timm.layers.norm_act.RmsNormAct
# Unsloth: Compiled timm.layers.norm_act.RmsNormAct2d
# Unsloth: Compiled timm.layers.norm_act.RmsNormAct2dFp32
# Unsloth: Compiled timm.layers.norm_act.RmsNormActFp32
# Unsloth: Compiled timm.layers.norm_act.SyncBatchNormAct
# Unsloth: Compiled timm.models._efficientnet_blocks.SqueezeExcite
# Unsloth: Compiled timm.models._efficientnet_blocks.ConvBnAct
# Unsloth: Compiled timm.models._efficientnet_blocks.DepthwiseSeparableConv
# Unsloth: Compiled timm.models._efficientnet_blocks.InvertedResidual
# Unsloth: Compiled timm.models._efficientnet_blocks.LayerScale2d
# Unsloth: Compiled timm.models._efficientnet_blocks.UniversalInvertedResidual
# Unsloth: Compiled timm.models._efficientnet_blocks.MobileAttention
# Unsloth: Compiled timm.models._efficientnet_blocks.EdgeResidual
# No module named 'causal_conv1d' No module named 'causal_conv1d'
# Unsloth: Failed compiling causal_conv1d
# Unsloth: Failed compiling mamba_ssm
# Unsloth: Patching LoRA to make it faster
# Unsloth: Not an error, but could not optimize some PEFT modules.
# []
# Unsloth: Will not compile SiglipEncoder since it looks like a vision encoder!
# Unsloth: Failed compiling function SiglipEncoder since there is padding done.
# Unsloth: Will not compile SiglipTextTransformer since it looks like a vision encoder!
# Unsloth: Failed compiling function SiglipTextTransformer since there is padding done.
# Unsloth: Will not compile SiglipVisionTransformer since it looks like a vision encoder!
# Unsloth: Compiled module SiglipVisionEmbeddings.
# Unsloth: Compiled module SiglipTextEmbeddings.
# Unsloth: Compiled module SiglipMLP.
# Unsloth: Compiled module SiglipMultiheadAttentionPoolingHead.
# Unsloth: Fast Attention patch for SiglipAttention.
# Unsloth: Compiled function _trunc_normal_.
# Unsloth: Compiled function trunc_normal_tf_.
# Unsloth: Compiled function variance_scaling_.
# Unsloth: Compiled function lecun_normal_.
# Unsloth: Compiled function default_flax_embed_init.
# Unsloth: Compiled function eager_attention_forward.
# Unsloth: Compiled timm.layers.fast_norm
# No module named 'causal_conv1d' No module named 'causal_conv1d'
# Unsloth: Failed compiling causal_conv1d
# Unsloth: Failed compiling mamba_ssm
# Unsloth: Patching LoRA to make it faster
# Unsloth: Not an error, but could not optimize some PEFT modules.
# Unsloth: Not an error, but could not optimize some PEFT modules.
# []
# Unsloth: Upcasting layernorm weights to float32
# Unsloth: Disabling compile for GptOssExperts since it's marked for disabling.
# Unsloth: Disabling compile for GptOssMLP since it's marked for disabling.
# Unsloth: Compiled module GptOssRMSNorm.
# Unsloth: Compiled module GptOssRotaryEmbedding.
# Unsloth: Slow Attention patch for GptOssTopKRouter.
# (2) Unsloth skipping patching fast linear cross entropy for GptOssForCausalLM
# [2/3 pattern] Successfully patched fast linear cross entropy for GptOssForCausalLM
# Unsloth: Fast fused linear cross entropy patch for GptOssForCausalLM.
# Unsloth: Fixed up function apply_rotary_pos_emb.
# Unsloth: Compiled function repeat_kv.
# Unsloth: Compiled function _apply_rotary_emb.
# Unsloth: Compiled function eager_attention_forward.
# Unsloth: Compiled function load_balancing_loss_func.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3Processor.__call__.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3RMSNorm.forward.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3Attention.forward.
# ERROR:unsloth_zoo.log:Unsloth: Skipped Gemma3Attention.forward
# Reason: Parameter 'past_key_value' signature changed
# ERROR:unsloth_zoo.log:Unsloth: Skipped CsmDepthDecoderForCausalLM.forward
# Reason: New function removed output_attentions and output_hidden_states
# INFO:unsloth_zoo.log:Unsloth: Patched CsmDepthDecoderForCausalLM.forward.
# ERROR:unsloth_zoo.log:Unsloth: Skipped CsmForConditionalGeneration.forward
# Reason: New function removed output_attentions and output_hidden_states
# INFO:unsloth_zoo.log:Unsloth: Patched CsmForConditionalGeneration.forward.
# INFO:unsloth_zoo.log:Unsloth: Patched CsmForConditionalGeneration._merge_input_ids_with_input_values.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3nTextAltUp.predict.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3nTextAltUp.correct.
# INFO:unsloth_zoo.log:Unsloth: Patched Gemma3nTextAltUp.scale_corrected_output.
# ERROR:unsloth_zoo.log:Unsloth: Skipped Gemma3nModel.get_placeholder_mask
# Reason: Parameter 'input_ids' changed from optional to required
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.swizzle_mxfp4.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.Mxfp4GptOssExperts.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.mlp_forward.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.load_and_swizzle_mxfp4.
# INFO:unsloth_zoo.log:Unsloth: Patched transformers.integrations.mxfp4.replace_with_mxfp4_linear.
# INFO:unsloth_zoo.log:Unsloth: Patched GptOssAttention.forward.
# ERROR:unsloth_zoo.log:Unsloth: Skipped GptOssAttention.forward
# Reason: Parameter 'past_key_value' signature changed
# INFO:unsloth_zoo.log:Unsloth: Patched PixtralAttention.__init__.
# INFO:unsloth_zoo.log:Unsloth: Patched PixtralAttention.forward.
# Unsloth: Successfully added convert_moe_packed_tensors_cpu function.
# ==((====))==  Unsloth 2025.9.1: Fast Gpt_Oss patching. Transformers: 4.55.4.
#    \\   /|    NVIDIA A100-SXM4-80GB. Num GPUs = 1. Max memory: 79.318 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 8.0. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Gpt_Oss does not support SDPA - switching to fast eager.
# Loading checkpoint shards:   0%|          | 0/16 [00:00<?, ?it/s]

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 8, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# ### Reasoning Effort
# The `gpt-oss` models from OpenAI include a feature that allows users to adjust the model's "reasoning effort." This gives you control over the trade-off between the model's performance and its response speed (latency) which by the amount of token the model will use to think.
#
# ----
#
# The `gpt-oss` models offer three distinct levels of reasoning effort you can choose from:
#
# * **Low**: Optimized for tasks that need very fast responses and don't require complex, multi-step reasoning.
# * **Medium**: A balance between performance and speed.
# * **High**: Provides the strongest reasoning performance for tasks that require it, though this results in higher latency.

# %%
from transformers import TextStreamer

messages = [
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "low", # **NEW!** Set reasoning effort to low, medium or high
).to(model.device)

_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-09-05
#
# Reasoning: low
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 =
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  7.09it/s, triton_poi_fused__to_copy_cos_sin_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 6/6 [00:00<00:00,  6.68it/s, triton_poi_fused_clone_5]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 384.94it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:10<00:00,  5.16s/it, triton_poi_fused__softmax__to_copy_scatter_zeros_like_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  2.40it/s, triton_poi_fused__to_copy_add_clamp_mul_sigmoid_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  6.28it/s, triton_red_fused_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 3/3 [00:08<00:00,  2.96s/it, triton_poi_fused__softmax__to_copy_scatter_zeros_like_2]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s, triton_poi_fused_add_clamp_mul_sigmoid_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 13.74it/s, triton_poi_fused__to_copy_cos_sin_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  6.25it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 14.58it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 3/3 [00:00<00:00, 11.06it/s, triton_poi_fused_clone_2]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 537.39it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 12.75it/s, triton_poi_fused__softmax__to_copy_scatter_zeros_like_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  2.77it/s, triton_poi_fused__to_copy_add_clamp_mul_sigmoid_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  6.54it/s, triton_red_fused_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 3/3 [00:00<00:00, 14.74it/s, triton_poi_fused__softmax__to_copy_scatter_zeros_like_2]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00,  2.95it/s, triton_poi_fused_add_clamp_mul_sigmoid_0]
# INFO:unsloth_compiled_module_gpt_oss:Unsloth: Removing compiler guards after 1 inference run. DYNAMO_STANCE.stance = eager_on_recompile DYNAMO_STANCE.skip_guard_eval_unsafe = False
# 3.<|end|><|start|>assistant<|channel|>analysis<|message|>Equation: x^5 + 3x^4 - 10 = 3 => x^5 + 3x^4 - 13 = 0. Solve polynomial. Likely find real root approximate. Let's use Python? We can approximate numeric roots. Let's brute: try integer small.

# %% [markdown]
# Changing the `reasoning_effort` to `medium` will make the model think longer. We have to increase the `max_new_tokens` to occupy the amount of the generated tokens but it will give better and more correct answer

# %%
from transformers import TextStreamer

messages = [
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "medium", # **NEW!** Set reasoning effort to low, medium or high
).to(model.device)

_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-08-13
#
# Reasoning: medium
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>The user: "Solve x^5 + 3x^4 - 10 = 3." Wait maybe it's an equation: x^5 + 3x^4 - 10 = 3. The variable x unknown. Solve for x. We need to solve the equation:
#
# x^

# %% [markdown]
# Lastly we will test it using `reasoning_effort` to `high`

# %%
from transformers import TextStreamer

messages = [
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "high", # **NEW!** Set reasoning effort to low, medium or high
).to(model.device)

_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-08-13
#
# Reasoning: high
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>We need to solve the equation: x^5 + 3x^4 - 10 = 3. Or maybe it's x^5 + 3x^4 - 10 = 3? That seems like a polynomial equation: x^5 + 3x^4 - 10

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep

# %% [markdown]
# The `HuggingFaceH4/Multilingual-Thinking` dataset will be utilized as our example. This dataset, available on Hugging Face, contains reasoning chain-of-thought examples derived from user questions that have been translated from English into four other languages. It is also the same dataset referenced in OpenAI's [cookbook](https://cookbook.openai.com/articles/gpt-oss/fine-tune-transfomers) for fine-tuning. The purpose of using this dataset is to enable the model to learn and develop reasoning capabilities in these four distinct languages.

# %%
def formatting_prompts_func(examples):
    convos = examples["messages"]
    texts = [tokenizer.apply_chat_template(convo, tokenize = False, add_generation_prompt = False) for convo in convos]
    return { "text" : texts, }
pass

from datasets import load_dataset

dataset = load_dataset("HuggingFaceH4/Multilingual-Thinking", split="train")
dataset
# Out:
# Dataset({
#     features: ['reasoning_language', 'developer', 'user', 'analysis', 'final', 'messages'],
#     num_rows: 1000
# })

# %% [markdown]
# To format our dataset, we will apply our version of the GPT OSS prompt

# %%
from unsloth.chat_templates import standardize_sharegpt
dataset = standardize_sharegpt(dataset)
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %% [markdown]
# Let's take a look at the dataset, and check what the 1st example shows

# %%
print(dataset[0]['text'])
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-09-05
#
# Reasoning: medium
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>developer<|message|># Instructions
#
# reasoning language: French
#
# You are an AI chatbot with a lively and energetic personality.<|end|><|start|>user<|message|>Can you show me the latest trends on Twitter right now?<|end|><|start|>assistant<|channel|>analysis<|message|>D'accord, l'utilisateur demande les tendances Twitter les plus récentes. Tout d'abord, je dois vérifier si j'ai accès à des données en temps réel. Étant donné que je ne peux pas naviguer sur Internet ou accéder directement à l'API de Twitter, je ne peux pas fournir des tendances en direct. Cependant, je peux donner quelques conseils généraux sur la façon de les trouver.
#
# Je devrais préciser que les tendances Twitter évoluent rapidement et sont spécifiques à chaque région. Je pourrais suggérer de consulter la section « En vogue » sur l'application ou le site web. Aussi, l'utilisation de hashtags et le suivi d'utilisateurs pertinents pourraient être utiles. Il est important de souligner que les tendances varient selon la région et l'heure de la journée. Je devrais garder un ton amical et bienveillant, peut-être ajouter un emoji pour rester léger. Je vais structurer ma réponse étape par étape pour faciliter la lecture. Je dois m'excuser de ne pas pouvoir fournir des données en temps réel et proposer d'autres méthodes. Je conserverai un langage simple et convivial, en évitant les termes techniques.<|end|><|start|>assistant<|channel|>final<|message|>Hey there!  While I can't check Twitter (X) in real-time or access live data, I can share some tips to help you spot the latest trends:
#
# 1. **Open the "Trending" tab** on the Twitter app or website – it updates constantly!
# 2. **Search for hashtags** like #Trending or #Viral to see what’s blowing up.
# 3. **Follow accounts** that curate trends (e.g., @TrendingNow, @ViralThreads).
# 4. **Check regional trends** – they often differ by location!
#
# Remember, trends are *super fast-moving* and often tied to pop culture, memes, or breaking news. For example, recent trends have included viral challenges (like the "Distracted Boyfriend" meme revival), celebrity drama, or unexpected events (hello, weather disasters!).
#
# Want me to brainstorm *what* might trend next? I’ve got ideas!<|return|>

# %% [markdown]
# What is unique about GPT-OSS is that it uses OpenAI [Harmony](https://github.com/openai/harmony) format which support conversation structures, reasoning output, and tool calling.

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's train our model. We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`.

# %%
from trl import SFTConfig, SFTTrainer
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    args = SFTConfig(
        per_device_train_batch_size = 1,
        gradient_accumulation_steps = 4,
        warmup_steps = 1,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 5,
        learning_rate = 2e-4,
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 12.811 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,000 | Num Epochs = 1 | Total steps = 5
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 4 x 1) = 4
#  "-____-"     Trainable parameters = 5,971,968 of 116,835,128,640 (0.01% trained)
# INFO:unsloth_zoo.log:Unsloth: num_items_in_batch = 3731
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  7.80it/s, triton_poi_fused__to_copy_cos_sin_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 473.08it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  5.30it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 419.72it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 432.14it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  7.02it/s, triton_poi_fused__softmax__to_copy_scatter_zeros_like_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 451.19it/s, triton_poi_fused__to_copy_add_clamp_mul_sigmoid_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 420.14it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 563.90it/s, triton_poi_fused__to_copy_add_clamp_mul_sigmoid_0]
# Unsloth: Compiling kernels: 0it [00:00, ?it/s]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 329.82it/s, triton_red_fused__to_copy_mean_mul_pow_rsqrt_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 308.70it/s, triton_red_fused__to_copy_add_div_mul_pow_sum_0]
# Unsloth: Compiling kernels: 100%|██████████| 3/3 [00:00<00:00, 521.16it/s, triton_poi_fused_2]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  6.03it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 342.42it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  7.19it/s, triton_poi_fused_zeros_like_1]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  5.89it/s, triton_poi_fused__softmax__softmax_backward_data__to_copy_scatter_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 521.10it/s, cpp_fused_0]
# Unsloth: Compiling kernels: 0it [00:00, ?it/s]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 502.07it/s, triton_poi_fused__to_copy_add_clamp_mul_sigmoid_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 342.08it/s, triton_poi_fused__to_copy_add_clamp_ge_le_logical_and_mul_scalar_tensor_sigmoid_sigmoid_backward_slice_backward_where_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 623.13it/s, triton_poi_fused__to_copy_add_clamp_mul_sigmoid_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 495.31it/s, triton_poi_fused__to_copy_add_clamp_ge_le_logical_and_mul_scalar_tensor_sigmoid_sigmoid_backward_slice_backward_where_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:06<00:00,  3.26s/it, triton_tem_fused_zeros_1]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00,  7.87it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 314.13it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:06<00:00,  3.36s/it, triton_tem_fused_zeros_1]
# Unsloth: Will smartly offload gradients to save VRAM!
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 659.17it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 428.25it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 449.02it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 582.91it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:00<00:00, 276.82it/s, triton_poi_fused_cat_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 333.23it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:06<00:00,  3.20s/it, triton_tem_fused_zeros_1]
# Unsloth: Compiling kernels: 100%|██████████| 1/1 [00:00<00:00, 391.22it/s, triton_tem_fused_0]
# Unsloth: Compiling kernels: 100%|██████████| 2/2 [00:06<00:00,  3.28s/it, triton_tem_fused_zeros_1]
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 04:07, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.545100</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.789400</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.510200</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.136100</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.002500</td>
#     </tr>
#   </tbody>
# </table><p>
# INFO:unsloth_zoo.log:Unsloth: num_items_in_batch = 3660
# INFO:unsloth_zoo.log:Unsloth: num_items_in_batch = 2944
# INFO:unsloth_zoo.log:Unsloth: num_items_in_batch = 4038
# INFO:unsloth_zoo.log:Unsloth: num_items_in_batch = 3849

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 645.6936 seconds used for training.
# 10.76 minutes used for training.
# Peak reserved memory = 12.975 GB.
# Peak reserved memory for training = 0.164 GB.
# Peak reserved memory % of max memory = 88.02 %.
# Peak reserved memory for training % of max memory = 1.113 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
messages = [
    {"role": "system", "content": "reasoning language: French\n\nYou are a helpful assistant that can solve mathematical problems."},
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "medium",
).to(model.device)
from transformers import TextStreamer
_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-09-05
#
# Reasoning: medium
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>developer<|message|># Instructions
#
# reasoning language: French
#
# You are a helpful assistant that can solve mathematical problems.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>j] = \) + 2+1e18, we need to useEffect {2} = {
#     print(padding 4 = f.
#
# Thus I have a and that a function that for the `java.rmi.RemoteException as 'P(N, and a(2, then a * @a

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** Currently finetunes can only be loaded via Unsloth in the meantime - we're working on vLLM and GGUF exporting!

# %%
model.save_pretrained("lora_model")
# model.push_to_hub("hf_username/finetuned_model", token = "hf_...") # Save to HF

# %% [markdown]
# To run the finetuned model, you can do the below after setting `if False` to `if True` in a new instance.

# %%
# %%time
if True: model.save_pretrained_merged("finetuned_model", tokenizer)
# Out:
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model-00000-of-00014.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Merging weights into 16bit:   0%|          | 0/15 [00:00<?, ?it/s]
# model-00000-of-00014.safetensors:   0%|          | 0.00/4.63G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.25.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.25.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.25.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.25.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 13.31 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.26.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.26.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 11.40 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.26.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.26.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 18.99 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.27.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.27.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:   7%|▋         | 1/15 [02:05<29:13, 125.25s/it]
# model-00001-of-00014.safetensors:   0%|          | 0.00/4.12G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.27.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.27.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.28.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.28.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 15.22 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.28.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.28.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.29.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.29.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.29.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.29.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  13%|█▎        | 2/15 [04:16<27:52, 128.65s/it]
# model-00002-of-00014.safetensors:   0%|          | 0.00/4.63G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 18.99 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.2.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.2.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.06 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.2.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.2.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 13.24 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.20.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.20.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 18.99 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.3.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.3.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.06 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.3.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.3.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  20%|██        | 3/15 [06:32<26:22, 131.88s/it]
# model-00003-of-00014.safetensors:   0%|          | 0.00/4.12G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.20.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.20.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.21.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.21.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 15.22 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.21.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.21.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.22.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.22.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.22.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.22.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  27%|██▋       | 4/15 [08:26<22:56, 125.11s/it]
# model-00004-of-00014.safetensors:   0%|          | 0.00/4.63G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.01 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.23.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.23.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.10 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.23.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.23.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 13.27 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.24.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.24.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 11.36 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.24.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.24.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 18.95 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.4.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.4.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  33%|███▎      | 5/15 [10:29<20:43, 124.39s/it]
# model-00005-of-00014.safetensors:   0%|          | 0.00/4.12G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 15.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.4.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.4.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.5.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.5.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 15.20 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.5.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.5.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 11.33 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.6.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.6.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 9.43 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.6.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.6.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  40%|████      | 6/15 [12:31<18:29, 123.33s/it]
# model-00006-of-00014.safetensors:   0%|          | 0.00/4.63G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.7.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.7.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.7.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.7.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 13.31 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.8.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.8.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 11.40 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.8.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.8.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 19.01 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.9.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.9.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  47%|████▋     | 7/15 [14:44<16:54, 126.75s/it]
# model-00007-of-00014.safetensors:   0%|          | 0.00/4.06G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 19.04 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.14.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.14.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 33,554,432 rows per chunk (max_gpu) - Need: 15.69 GB, Available: 17.13 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.14.mlp.experts.gate_up_proj with 33,554,432 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.14.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 13.31 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.15.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.15.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 11.40 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.15.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.15.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 18.99 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.9.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.9.mlp.experts.down_proj
# Unsloth: Merging weights into 16bit:  53%|█████▎    | 8/15 [16:43<14:29, 124.16s/it]
# model-00008-of-00014.safetensors:   0%|          | 0.00/4.63G [00:00<?, ?B/s]
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 17.06 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.16.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.16.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 15.17 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.16.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.16.mlp.experts.gate_up_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 3.91 GB, Available: 11.34 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.17.mlp.experts.down_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.17.mlp.experts.down_proj
# INFO:unsloth_zoo.log:[MXFP4] Selected cuda: with 4,194,304 rows per chunk (large) - Need: 6.50 GB, Available: 9.45 GB
# INFO:unsloth_zoo.log:[DEBUG] Using GPU dequantization for model.layers.17.mlp.experts.gate_up_proj with 4,194,304 rows per chunk
# INFO:unsloth_zoo.log:[DEBUG] DEQUANTIZING MXFP4 Key Group: model.layers.17.mlp.experts.gate_up_proj
# Unsloth: Merging weights into 16bit:  53%|█████▎    | 8/15 [17:32<15:21, 131.57s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     966         with _open_zipfile_writer(f) as opened_zipfile:
# --> 967             _save(
#     968                 obj,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1267             # Now that it is on the CPU we can directly copy it into the zip file
# -> 1268             zip_file.write_record(name, storage, num_bytes)
#    1269
#
# RuntimeError: [enforce fail at inline_container.cc:858] . PytorchStreamWriter failed writing file data/0: file write failed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.12/dist-packages/unsloth/save.py in unsloth_generic_save_pretrained_merged(self, save_directory, tokenizer, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, tags, temporary_location, maximum_memory_usage)
#    2448     arguments["model"] = self
#    2449     del arguments["self"]
# -> 2450     unsloth_generic_save(**arguments)
#    2451     for _ in range(3):
#    2452         gc.collect()
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/unsloth/save.py in unsloth_generic_save(model, tokenizer, save_directory, save_method, push_to_hub, token, is_main_process, state_dict, save_function, max_shard_size, safe_serialization, variant, save_peft_format, use_temp_dir, commit_message, private, create_pr, revision, commit_description, tags, temporary_location, maximum_memory_usage)
#    2394         save_method = "merged_4bit"
#    2395
# -> 2396     merge_and_overwrite_lora(
#    2397         get_model_name,
#    2398         model                = model,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/saving_utils.py in merge_and_overwrite_lora(get_model_name, model, tokenizer, save_directory, push_to_hub, private, token, save_method, output_dtype, low_disk_space_usage, use_temp_file, cleanup_temp_file)
#     972             )
#     973         pass
# --> 974         n_saved_modules += _merge_and_overwrite_lora(
#     975             save_directory = save_directory,
#     976             filename = filename,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/unsloth_zoo/saving_utils.py in _merge_and_overwrite_lora(save_directory, filename, lora_weights, output_dtype, model_class_name, base_model_is_quantized, quant_type)
#     480                 temp_filename = temp_file.name
#     481                 # Save the merged tensor to a unique temp file
# --> 482                 torch.save(W.to(output_dtype), temp_filename, pickle_module=pickle, pickle_protocol=pickle.HIGHEST_PROTOCOL)
#     483                 # Load it back as a memory-mapped object. The OS will manage paging this from disk.
#     484                 W = torch.load(temp_filename, map_location="cpu", mmap=True, weights_only=False)
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     964
#     965     if _use_new_zipfile_serialization:
# --> 966         with _open_zipfile_writer(f) as opened_zipfile:
#     967             _save(
#     968                 obj,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in __exit__(self, *args)
#     796
#     797     def __exit__(self, *args) -> None:
# --> 798         self.file_like.write_end_of_file()
#     799         if self.file_stream is not None:
#     800             self.file_stream.close()
#
# RuntimeError: [enforce fail at inline_container.cc:664] . unexpected pos 704 vs 598

# %%
model
# Out:
# PeftModel(
#   (base_model): LoraModel(
#     (model): GptOssForCausalLM(
#       (model): GptOssModel(
#         (embed_tokens): Embedding(201088, 2880, padding_idx=200017)
#         (layers): ModuleList(
#           (0-35): 36 x GptOssDecoderLayer(
#             (self_attn): GptOssAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2880, out_features=4096, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2880, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2880, out_features=512, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2880, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=2880, out_features=512, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2880, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=512, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=2880, bias=True)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2880, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): GptOssMLP(
#               (router): GptOssTopKRouter(
#                 (linear): Linear(in_features=2880, out_features=128, bias=True)
#               )
#               (experts): GptOssExperts(
#                 (gate_up_projs): ModuleList(
#                   (0-127): 128 x Linear4bit(in_features=2880, out_features=5760, bias=True)
#                 )
#                 (down_projs): ModuleList(
#                   (0-127): 128 x Linear4bit(in_features=2880, out_features=2880, bias=True)
#                 )
#               )
#             )
#             (input_layernorm): GptOssRMSNorm((2880,), eps=1e-05)
#             (post_attention_layernorm): GptOssRMSNorm((2880,), eps=1e-05)
#           )
#         )
#         (norm): GptOssRMSNorm((2880,), eps=1e-05)
#         (rotary_emb): GptOssRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=2880, out_features=201088, bias=False)
#     )
#   )
# )

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "finetuned_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = 1024,
        dtype = None,
        load_in_4bit = True,
    )

messages = [
    {"role": "system", "content": "reasoning language: French\n\nYou are a helpful assistant that can solve mathematical problems."},
    {"role": "user", "content": "Solve x^5 + 3x^4 - 10 = 3."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True,
    return_tensors = "pt",
    return_dict = True,
    reasoning_effort = "high",
).to(model.device)
from transformers import TextStreamer
_ = model.generate(**inputs, max_new_tokens = 64, streamer = TextStreamer(tokenizer))
# Out:
# <|start|>system<|message|>You are ChatGPT, a large language model trained by OpenAI.
# Knowledge cutoff: 2024-06
# Current date: 2025-08-13
#
# Reasoning: high
#
# # Valid channels: analysis, commentary, final. Channel must be included for every message.
# Calls to these tools must go to the commentary channel: 'functions'.<|end|><|start|>developer<|message|># Instructions
#
# reasoning language: French
#
# You are a helpful assistant that can solve mathematical problems.<|end|><|start|>user<|message|>Solve x^5 + 3x^4 - 10 = 3.<|end|><|start|>assistant<|channel|>analysis<|message|>We need to solve the equation for x. The equation: x^5 + 3x^4 - 10 = 3. So bring 3 to left side: x^5 + 3x^4 -10 -3 = 0 → x^5 + 3x^

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
